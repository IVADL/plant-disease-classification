# %% [markdown]
# # Model

# %%
from model import ClassificationModel

# %%
# Get Image Size
import PIL
image = PIL.Image.open("dataset\\test\\Tomato___Tomato_Yellow_Leaf_Curl_Virus\\image (999).JPG")
width, height = image.size
print(image.size)
# Out:
# (256, 256)

# %%
f = open("dataset/label.txt", 'r')
lines = f.readlines()
label = []
for line in lines:
    label.append(line.strip('\n'))
f.close()

print(label)
# Out:
# ['Apple___Apple_scab', 'Apple___Black_rot', 'Apple___Cedar_apple_rust', 'Apple___healthy', 'Background_without_leaves', 'Blueberry___healthy', 'Cherry___healthy', 'Cherry___Powdery_mildew', 'Corn___Cercospora_leaf_spot Gray_leaf_spot', 'Corn___Common_rust', 'Corn___healthy', 'Corn___Northern_Leaf_Blight', 'Grape___Black_rot', 'Grape___Esca_(Black_Measles)', 'Grape___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Orange___Haunglongbing_(Citrus_greening)', 'Peach___Bacterial_spot', 'Peach___healthy', 'Pepper,_bell___Bacterial_spot', 'Pepper,_bell___healthy', 'Potato___Early_blight', 'Potato___healthy', 'Potato___Late_blight', 'Raspberry___healthy', 'Soybean___healthy', 'Squash___Powdery_mildew', 'Strawberry___healthy', 'Strawberry___Leaf_scorch', 'Tomato___Bacterial_spot', 'Tomato___Early_blight', 'Tomato___healthy', 'Tomato___Late_blight', 'Tomato___Leaf_Mold', 'Tomato___Septoria_leaf_spot', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Tomato___Target_Spot', 'Tomato___T
# ...

# %%
model = ClassificationModel(
            class_list=label,
            img_width=width,
            img_height=height,
            batch_size=16,
        )

# %%
model.generate_train_val_data(data_dir="dataset/train/")
# Out:
# Found 39351 images belonging to 39 classes.
# Found 9828 images belonging to 39 classes.

# %%
status = model.set_model(model_name="inception_v3")
if status:
    print('ready model.')
# Out:
# ...
# 87916544/87910968 [==============================] - 6s 0us/step
# ready model.

# %%
history = model.train(epochs=10)
# Out:
# WARNING:tensorflow:From d:\dev\workspace\plant-disease-classification\inception_v3.py:126: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/10
# ...
# 2458/2458 [==============================] - ETA: 0s - loss: 2.1937 - accuracy: 0.5468
# Epoch 00001: val_loss improved from inf to 0.82027, saving model to models/checkpoint\checkpoint_202101271650.hdf5
# 2458/2458 [==============================] - 931s 379ms/step - loss: 2.1937 - accuracy: 0.5468 - val_loss: 0.8203 - val_accuracy: 0.8770
# Epoch 2/10
# 2458/2458 [==============================] - ETA: 0s - loss: 0.8361 - accuracy: 0.8622
# Epoch 00002: val_loss improved from 0.82027 to 0.47506, saving model to models/checkpoint\checkpoint_202101271650.hdf5
# ...

# %%
model.show_accuracy()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-3066ff977fe3> in <module>
# ----> 1 model.show_accuracy()
#
# d:\dev\workspace\plant-disease-classification\inception_v3.py in show_accuracy(self)
#     227             plt.legend(["train_acc", "val_acc"], loc="best")
#     228             plt.show()
# --> 229             plt.savefig("results/accuracy_model_{}.png".format(self.day_now))
#     230         else:
#     231             print("Model not found... : load_model or train plz")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ...

# %%
model.show_loss()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-955fbdb07d73> in <module>
# ----> 1 model.show_loss()
#
# d:\dev\workspace\plant-disease-classification\inception_v3.py in show_loss(self)
#     245             plt.legend(["train_loss", "val_loss"], loc="best")
#     246             plt.show()
# --> 247             plt.savefig("results/loss_model_{}.png".format(self.day_now))
#     248         else:
#     249             print("Model not found... : load_model or train plz")
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ...

# %%
model.evaluation(batch_size=16, data_dir="dataset/test/")
# Out:
# Found 12307 images belonging to 39 classes.
# WARNING:tensorflow:From d:\dev\workspace\plant-disease-classification\inception_v3.py:152: Model.evaluate_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.evaluate, which supports generators.
# Evaluation data: dataset/test/
# accuracy: 100.00%

# %%
file_path = "dataset\\test\\Tomato___Tomato_Yellow_Leaf_Curl_Virus\\image (999).JPG"
display(image)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=256x256 at 0x27DEB6F1970>

# %%
model.prediction(file_path)
# Out:
# [Model Prediction] dataset\test\Tomato___Tomato_Yellow_Leaf_Curl_Virus\image (999): Tomato___Tomato_Yellow_Leaf_Curl_Virus
# 1
